# %%
import math
import matplotlib.pyplot as plt
from datetime import datetime

#colours
ts_teal = '#00DBBC'
ts_red ='#EB5347'
ts_yellow ='#EBC247'
ts_orange ='#FF8B25'
ts_purple ='#D65BB3'
ts_lblue ='#47C6EB'
ts_fusia ='#E82166'
ts_lime ='#BAEB47'
ts_sand ='#EB7347'
ts_dpurple ='#9747FF'
ts_pblue ='#87FFEE'
ts_dgreen ='#007564'
ts_gray ='#909090'
ts_green ='#00B20F'
ts_brown ='#BD7536'
ts_rblue ='#008BDB'

colours = [ts_teal,
            ts_red,
            ts_yellow,
            ts_orange ,
            ts_purple ,
            ts_lblue ,
            ts_fusia ,
            ts_lime ,
            ts_sand ,
            ts_dpurple ,
            ts_pblue ,
            ts_dgreen ,
            ts_gray ,
            ts_green ,
            ts_brown ,
            ts_rblue]

#plot in dark mode
plt.style.use('dark_background')

# %%
token_max = 21000000
blocks_day = 7200
days_entry = 10

# %%
## lets get all tao emission daily until we emit it all

def get_tao_blocks(do_print=False):
    tao_blocks =[]
    #first entry is dtao launch
    tao_blocks.append({"block":4920351, "timestamp":1739482871, "emitted_tao":8359419, "halving":0, "excess":0})
    
    
    counter = 0 
    
    emitted_tao  = 8359419
    timestamp = 1739482871
    halving = 0
    block = 4920351
    while emitted_tao < token_max-1:
        block +=7200*days_entry
        timestamp += 86400*days_entry
        emitted_tao += (7200*days_entry)*(0.5)**halving
        halving = math.floor(math.log((token_max - emitted_tao)/token_max)/math.log(0.5))
        #when we initilize - we have no idea of the excess - so place in a zero
        tao_blocks.append({"block":block, "timestamp":timestamp, "emitted_tao":emitted_tao, "halving":halving,"excess":0})
        if do_print:
            counter +=1
            if counter % 10 ==0:
                print({"block":block, "timestamp":timestamp, "emitted_tao":emitted_tao, "halving":halving,"excess":0})
    print(len(tao_blocks))
    return tao_blocks
tao_blocks = get_tao_blocks(True)
# Out:
# {'block': 5640351, 'timestamp': 1748122871, 'emitted_tao': 9079419.0, 'halving': 0, 'excess': 0}
# {'block': 6360351, 'timestamp': 1756762871, 'emitted_tao': 9799419.0, 'halving': 0, 'excess': 0}
# {'block': 7080351, 'timestamp': 1765402871, 'emitted_tao': 10519419.0, 'halving': 1, 'excess': 0}
# {'block': 7800351, 'timestamp': 1774042871, 'emitted_tao': 10879419.0, 'halving': 1, 'excess': 0}
# {'block': 8520351, 'timestamp': 1782682871, 'emitted_tao': 11239419.0, 'halving': 1, 'excess': 0}
# {'block': 9240351, 'timestamp': 1791322871, 'emitted_tao': 11599419.0, 'halving': 1, 'excess': 0}
# {'block': 9960351, 'timestamp': 1799962871, 'emitted_tao': 11959419.0, 'halving': 1, 'excess': 0}
# {'block': 10680351, 'timestamp': 1808602871, 'emitted_tao': 12319419.0, 'halving': 1, 'excess': 0}
# {'block': 11400351, 'timestamp': 1817242871, 'emitted_tao': 12679419.0, 'halving': 1, 'excess': 0}
# {'block': 12120351, 'timestamp': 1825882871, 'emitted_tao': 13039419.0, 'halving': 1, 'excess': 0}
# {'block': 12840351, 'timestamp': 1834522871, 'emitted_tao': 13399419.0, 'halving': 1, 'excess': 0}
# {'block': 13560351, 'timestamp': 1843162871, 'emitted_tao': 13759419.0, 'halving': 1, 'excess': 0}
# {'block': 14280351, 'timestamp': 1851802871, 'emitted_tao': 14119419.0, 'halving': 1, 'excess': 0}
# {'block': 15000351, 'timestamp': 1860442871, 'emitted_tao': 14479419.0, 'halving': 1, 'excess': 0}
# {'block': 15720351, 'timestamp': 1869082871, 'emitted_tao': 14839419.0, 'halving': 1, 'excess': 0}
# {'block': 16440351, 'timestamp': 1877722871, 'emitted_tao': 15199419.0, 'halving': 1, 'excess': 0}
# {'block': 17160351, 'timestamp': 1886362871, 'emitted_tao': 15559419.0, 'halving': 1, 'excess': 0}
# {'block': 17880351, 'timestamp': 1895002871, 'emitted_tao': 15847419.0, 'halving': 2, 'excess': 0}
# {'block': 18600351, 'timestamp': 1903642871, 'emitted_tao': 16027419.0, 'halving': 2, 'excess': 0}
# {'block': 19320351, 'timestamp': 1912282871, 'emitted_tao': 16207419.0, 'halving': 2, 'excess': 0}
# {'block': 20040351, 'timestamp': 1920922871, 'emitted_tao': 16387419.0, 'halving': 2, 'excess': 0}
# {'block': 20760351, 'timestamp': 1929562871, 'emitted_tao': 16567419.0, 'halving': 2, 'excess': 0}
# {'block': 21480351, 'timestamp': 1938202871, 'emitted_tao': 16747419.0, 'halving': 2, 'excess': 0}
# {'block': 22200351, 'timestamp': 1946842871, 'emitted_tao': 16927419.0, 'halving': 2, 'excess': 0}
# {'block': 22920351, 'timestamp': 1955482871, 'emitted_tao': 17107419.0, 'halving': 2, 'excess': 0}
# {'block': 23640351, 'timestamp': 1964122871, 'emitted_tao': 17287419.0, 'halving': 2, 'excess': 0}
# {'block': 24360351, 'timestamp': 1972762871, 'emitted_tao': 17467419.0, 'halving': 2, 'excess': 0}
# {'block': 25080351, 'timestamp': 1981402871, 'emitted_tao': 17647419.0, 'halving': 2, 'excess': 0}
# {'block': 25800351, 'timestamp': 1990042871, 'emitted_tao': 17827419.0, 'halving': 2, 'excess': 0}
# {'block': 26520351, 'timestamp': 1998682871, 'emitted_tao': 18007419.0, 'halving': 2, 'excess': 0}
# {'block': 27240351, 'timestamp': 2007322871, 'emitted_tao': 18187419.0, 'halving': 2, 'excess': 0}
# {'block': 27960351, 'timestamp': 2015962871, 'emitted_tao': 18367419.0, 'halving': 2, 'excess': 0}
# {'block': 28680351, 'timestamp': 2024602871, 'emitted_tao': 18466419.0, 'halving': 3, 'excess': 0}
# {'block': 29400351, 'timestamp': 2033242871, 'emitted_tao': 18556419.0, 'halving': 3, 'excess': 0}
# {'block': 30120351, 'timestamp': 2041882871, 'emitted_tao': 18646419.0, 'halving': 3, 'excess': 0}
# {'block': 30840351, 'timestamp': 2050522871, 'emitted_tao': 18736419.0, 'halving': 3, 'excess': 0}
# {'block': 31560351, 'timestamp': 2059162871, 'emitted_tao': 18826419.0, 'halving': 3, 'excess': 0}
# {'block': 32280351, 'timestamp': 2067802871, 'emitted_tao': 18916419.0, 'halving': 3, 'excess': 0}
# {'block': 33000351, 'timestamp': 2076442871, 'emitted_tao': 19006419.0, 'halving': 3, 'excess': 0}
# {'block': 33720351, 'timestamp': 2085082871, 'emitted_tao': 19096419.0, 'halving': 3, 'excess': 0}
# {'block': 34440351, 'timestamp': 2093722871, 'emitted_tao': 19186419.0, 'halving': 3, 'excess': 0}
# {'block': 35160351, 'timestamp': 2102362871, 'emitted_tao': 19276419.0, 'halving': 3, 'excess': 0}
# {'block': 35880351, 'timestamp': 2111002871, 'emitted_tao': 19366419.0, 'halving': 3, 'excess': 0}
# {'block': 36600351, 'timestamp': 2119642871, 'emitted_tao': 19456419.0, 'halving': 3, 'excess': 0}
# {'block': 37320351, 'timestamp': 2128282871, 'emitted_tao': 19546419.0, 'halving': 3, 'excess': 0}
# {'block': 38040351, 'timestamp': 2136922871, 'emitted_tao': 19636419.0, 'halving': 3, 'excess': 0}
# {'block': 38760351, 'timestamp': 2145562871, 'emitted_tao': 19708419.0, 'halving': 4, 'excess': 0}
# {'block': 39480351, 'timestamp': 2154202871, 'emitted_tao': 19753419.0, 'halving': 4, 'excess': 0}
# {'block': 40200351, 'timestamp': 2162842871, 'emitted_tao': 19798419.0, 'halving': 4, 'excess': 0}
# {'block': 40920351, 'timestamp': 2171482871, 'emitted_tao': 19843419.0, 'halving': 4, 'excess': 0}
# {'block': 41640351, 'timestamp': 2180122871, 'emitted_tao': 19888419.0, 'halving': 4, 'excess': 0}
# {'block': 42360351, 'timestamp': 2188762871, 'emitted_tao': 19933419.0, 'halving': 4, 'excess': 0}
# {'block': 43080351, 'timestamp': 2197402871, 'emitted_tao': 19978419.0, 'halving': 4, 'excess': 0}
# {'block': 43800351, 'timestamp': 2206042871, 'emitted_tao': 20023419.0, 'halving': 4, 'excess': 0}
# {'block': 44520351, 'timestamp': 2214682871, 'emitted_tao': 20068419.0, 'halving': 4, 'excess': 0}
# {'block': 45240351, 'timestamp': 2223322871, 'emitted_tao': 20113419.0, 'halving': 4, 'excess': 0}
# {'block': 45960351, 'timestamp': 2231962871, 'emitted_tao': 20158419.0, 'halving': 4, 'excess': 0}
# {'block': 46680351, 'timestamp': 2240602871, 'emitted_tao': 20203419.0, 'halving': 4, 'excess': 0}
# {'block': 47400351, 'timestamp': 2249242871, 'emitted_tao': 20248419.0, 'halving': 4, 'excess': 0}
# {'block': 48120351, 'timestamp': 2257882871, 'emitted_tao': 20293419.0, 'halving': 4, 'excess': 0}
# {'block': 48840351, 'timestamp': 2266522871, 'emitted_tao': 20338419.0, 'halving': 4, 'excess': 0}
# {'block': 49560351, 'timestamp': 2275162871, 'emitted_tao': 20365419.0, 'halving': 5, 'excess': 0}
# {'block': 50280351, 'timestamp': 2283802871, 'emitted_tao': 20387919.0, 'halving': 5, 'excess': 0}
# {'block': 51000351, 'timestamp': 2292442871, 'emitted_tao': 20410419.0, 'halving': 5, 'excess': 0}
# {'block': 51720351, 'timestamp': 2301082871, 'emitted_tao': 20432919.0, 'halving': 5, 'excess': 0}
# {'block': 52440351, 'timestamp': 2309722871, 'emitted_tao': 20455419.0, 'halving': 5, 'excess': 0}
# {'block': 53160351, 'timestamp': 2318362871, 'emitted_tao': 20477919.0, 'halving': 5, 'excess': 0}
# {'block': 53880351, 'timestamp': 2327002871, 'emitted_tao': 20500419.0, 'halving': 5, 'excess': 0}
# {'block': 54600351, 'timestamp': 2335642871, 'emitted_tao': 20522919.0, 'halving': 5, 'excess': 0}
# {'block': 55320351, 'timestamp': 2344282871, 'emitted_tao': 20545419.0, 'halving': 5, 'excess': 0}
# {'block': 56040351, 'timestamp': 2352922871, 'emitted_tao': 20567919.0, 'halving': 5, 'excess': 0}
# {'block': 56760351, 'timestamp': 2361562871, 'emitted_tao': 20590419.0, 'halving': 5, 'excess': 0}
# {'block': 57480351, 'timestamp': 2370202871, 'emitted_tao': 20612919.0, 'halving': 5, 'excess': 0}
# {'block': 58200351, 'timestamp': 2378842871, 'emitted_tao': 20635419.0, 'halving': 5, 'excess': 0}
# {'block': 58920351, 'timestamp': 2387482871, 'emitted_tao': 20657919.0, 'halving': 5, 'excess': 0}
# {'block': 59640351, 'timestamp': 2396122871, 'emitted_tao': 20677044.0, 'halving': 6, 'excess': 0}
# {'block': 60360351, 'timestamp': 2404762871, 'emitted_tao': 20688294.0, 'halving': 6, 'excess': 0}
# {'block': 61080351, 'timestamp': 2413402871, 'emitted_tao': 20699544.0, 'halving': 6, 'excess': 0}
# {'block': 61800351, 'timestamp': 2422042871, 'emitted_tao': 20710794.0, 'halving': 6, 'excess': 0}
# {'block': 62520351, 'timestamp': 2430682871, 'emitted_tao': 20722044.0, 'halving': 6, 'excess': 0}
# {'block': 63240351, 'timestamp': 2439322871, 'emitted_tao': 20733294.0, 'halving': 6, 'excess': 0}
# {'block': 63960351, 'timestamp': 2447962871, 'emitted_tao': 20744544.0, 'halving': 6, 'excess': 0}
# {'block': 64680351, 'timestamp': 2456602871, 'emitted_tao': 20755794.0, 'halving': 6, 'excess': 0}
# {'block': 65400351, 'timestamp': 2465242871, 'emitted_tao': 20767044.0, 'halving': 6, 'excess': 0}
# {'block': 66120351, 'timestamp': 2473882871, 'emitted_tao': 20778294.0, 'halving': 6, 'excess': 0}
# {'block': 66840351, 'timestamp': 2482522871, 'emitted_tao': 20789544.0, 'halving': 6, 'excess': 0}
# {'block': 67560351, 'timestamp': 2491162871, 'emitted_tao': 20800794.0, 'halving': 6, 'excess': 0}
# {'block': 68280351, 'timestamp': 2499802871, 'emitted_tao': 20812044.0, 'halving': 6, 'excess': 0}
# {'block': 69000351, 'timestamp': 2508442871, 'emitted_tao': 20823294.0, 'halving': 6, 'excess': 0}
# {'block': 69720351, 'timestamp': 2517082871, 'emitted_tao': 20834544.0, 'halving': 6, 'excess': 0}
# {'block': 70440351, 'timestamp': 2525722871, 'emitted_tao': 20841294.0, 'halving': 7, 'excess': 0}
# {'block': 71160351, 'timestamp': 2534362871, 'emitted_tao': 20846919.0, 'halving': 7, 'excess': 0}
# {'block': 71880351, 'timestamp': 2543002871, 'emitted_tao': 20852544.0, 'halving': 7, 'excess': 0}
# {'block': 72600351, 'timestamp': 2551642871, 'emitted_tao': 20858169.0, 'halving': 7, 'excess': 0}
# {'block': 73320351, 'timestamp': 2560282871, 'emitted_tao': 20863794.0, 'halving': 7, 'excess': 0}
# {'block': 74040351, 'timestamp': 2568922871, 'emitted_tao': 20869419.0, 'halving': 7, 'excess': 0}
# {'block': 74760351, 'timestamp': 2577562871, 'emitted_tao': 20875044.0, 'halving': 7, 'excess': 0}
# {'block': 75480351, 'timestamp': 2586202871, 'emitted_tao': 20880669.0, 'halving': 7, 'excess': 0}
# {'block': 76200351, 'timestamp': 2594842871, 'emitted_tao': 20886294.0, 'halving': 7, 'excess': 0}
# {'block': 76920351, 'timestamp': 2603482871, 'emitted_tao': 20891919.0, 'halving': 7, 'excess': 0}
# {'block': 77640351, 'timestamp': 2612122871, 'emitted_tao': 20897544.0, 'halving': 7, 'excess': 0}
# {'block': 78360351, 'timestamp': 2620762871, 'emitted_tao': 20903169.0, 'halving': 7, 'excess': 0}
# {'block': 79080351, 'timestamp': 2629402871, 'emitted_tao': 20908794.0, 'halving': 7, 'excess': 0}
# {'block': 79800351, 'timestamp': 2638042871, 'emitted_tao': 20914419.0, 'halving': 7, 'excess': 0}
# {'block': 80520351, 'timestamp': 2646682871, 'emitted_tao': 20919200.25, 'halving': 8, 'excess': 0}
# {'block': 81240351, 'timestamp': 2655322871, 'emitted_tao': 20922012.75, 'halving': 8, 'excess': 0}
# {'block': 81960351, 'timestamp': 2663962871, 'emitted_tao': 20924825.25, 'halving': 8, 'excess': 0}
# {'block': 82680351, 'timestamp': 2672602871, 'emitted_tao': 20927637.75, 'halving': 8, 'excess': 0}
# {'block': 83400351, 'timestamp': 2681242871, 'emitted_tao': 20930450.25, 'halving': 8, 'excess': 0}
# {'block': 84120351, 'timestamp': 2689882871, 'emitted_tao': 20933262.75, 'halving': 8, 'excess': 0}
# {'block': 84840351, 'timestamp': 2698522871, 'emitted_tao': 20936075.25, 'halving': 8, 'excess': 0}
# {'block': 85560351, 'timestamp': 2707162871, 'emitted_tao': 20938887.75, 'halving': 8, 'excess': 0}
# {'block': 86280351, 'timestamp': 2715802871, 'emitted_tao': 20941700.25, 'halving': 8, 'excess': 0}
# {'block': 87000351, 'timestamp': 2724442871, 'emitted_tao': 20944512.75, 'halving': 8, 'excess': 0}
# {'block': 87720351, 'timestamp': 2733082871, 'emitted_tao': 20947325.25, 'halving': 8, 'excess': 0}
# {'block': 88440351, 'timestamp': 2741722871, 'emitted_tao': 20950137.75, 'halving': 8, 'excess': 0}
# {'block': 89160351, 'timestamp': 2750362871, 'emitted_tao': 20952950.25, 'halving': 8, 'excess': 0}
# {'block': 89880351, 'timestamp': 2759002871, 'emitted_tao': 20955762.75, 'halving': 8, 'excess': 0}
# {'block': 90600351, 'timestamp': 2767642871, 'emitted_tao': 20958575.25, 'halving': 8, 'excess': 0}
# {'block': 91320351, 'timestamp': 2776282871, 'emitted_tao': 20960262.75, 'halving': 9, 'excess': 0}
# {'block': 92040351, 'timestamp': 2784922871, 'emitted_tao': 20961669.0, 'halving': 9, 'excess': 0}
# {'block': 92760351, 'timestamp': 2793562871, 'emitted_tao': 20963075.25, 'halving': 9, 'excess': 0}
# {'block': 93480351, 'timestamp': 2802202871, 'emitted_tao': 20964481.5, 'halving': 9, 'excess': 0}
# {'block': 94200351, 'timestamp': 2810842871, 'emitted_tao': 20965887.75, 'halving': 9, 'excess': 0}
# {'block': 94920351, 'timestamp': 2819482871, 'emitted_tao': 20967294.0, 'halving': 9, 'excess': 0}
# {'block': 95640351, 'timestamp': 2828122871, 'emitted_tao': 20968700.25, 'halving': 9, 'excess': 0}
# {'block': 96360351, 'timestamp': 2836762871, 'emitted_tao': 20970106.5, 'halving': 9, 'excess': 0}
# {'block': 97080351, 'timestamp': 2845402871, 'emitted_tao': 20971512.75, 'halving': 9, 'excess': 0}
# {'block': 97800351, 'timestamp': 2854042871, 'emitted_tao': 20972919.0, 'halving': 9, 'excess': 0}
# {'block': 98520351, 'timestamp': 2862682871, 'emitted_tao': 20974325.25, 'halving': 9, 'excess': 0}
# {'block': 99240351, 'timestamp': 2871322871, 'emitted_tao': 20975731.5, 'halving': 9, 'excess': 0}
# {'block': 99960351, 'timestamp': 2879962871, 'emitted_tao': 20977137.75, 'halving': 9, 'excess': 0}
# {'block': 100680351, 'timestamp': 2888602871, 'emitted_tao': 20978544.0, 'halving': 9, 'excess': 0}
# {'block': 101400351, 'timestamp': 2897242871, 'emitted_tao': 20979739.3125, 'halving': 10, 'excess': 0}
# {'block': 102120351, 'timestamp': 2905882871, 'emitted_tao': 20980442.4375, 'halving': 10, 'excess': 0}
# {'block': 102840351, 'timestamp': 2914522871, 'emitted_tao': 20981145.5625, 'halving': 10, 'excess': 0}
# {'block': 103560351, 'timestamp': 2923162871, 'emitted_tao': 20981848.6875, 'halving': 10, 'excess': 0}
# {'block': 104280351, 'timestamp': 2931802871, 'emitted_tao': 20982551.8125, 'halving': 10, 'excess': 0}
# {'block': 105000351, 'timestamp': 2940442871, 'emitted_tao': 20983254.9375, 'halving': 10, 'excess': 0}
# {'block': 105720351, 'timestamp': 2949082871, 'emitted_tao': 20983958.0625, 'halving': 10, 'excess': 0}
# {'block': 106440351, 'timestamp': 2957722871, 'emitted_tao': 20984661.1875, 'halving': 10, 'excess': 0}
# {'block': 107160351, 'timestamp': 2966362871, 'emitted_tao': 20985364.3125, 'halving': 10, 'excess': 0}
# {'block': 107880351, 'timestamp': 2975002871, 'emitted_tao': 20986067.4375, 'halving': 10, 'excess': 0}
# {'block': 108600351, 'timestamp': 2983642871, 'emitted_tao': 20986770.5625, 'halving': 10, 'excess': 0}
# {'block': 109320351, 'timestamp': 2992282871, 'emitted_tao': 20987473.6875, 'halving': 10, 'excess': 0}
# {'block': 110040351, 'timestamp': 3000922871, 'emitted_tao': 20988176.8125, 'halving': 10, 'excess': 0}
# {'block': 110760351, 'timestamp': 3009562871, 'emitted_tao': 20988879.9375, 'halving': 10, 'excess': 0}
# {'block': 111480351, 'timestamp': 3018202871, 'emitted_tao': 20989583.0625, 'halving': 10, 'excess': 0}
# {'block': 112200351, 'timestamp': 3026842871, 'emitted_tao': 20990040.09375, 'halving': 11, 'excess': 0}
# {'block': 112920351, 'timestamp': 3035482871, 'emitted_tao': 20990391.65625, 'halving': 11, 'excess': 0}
# {'block': 113640351, 'timestamp': 3044122871, 'emitted_tao': 20990743.21875, 'halving': 11, 'excess': 0}
# {'block': 114360351, 'timestamp': 3052762871, 'emitted_tao': 20991094.78125, 'halving': 11, 'excess': 0}
# {'block': 115080351, 'timestamp': 3061402871, 'emitted_tao': 20991446.34375, 'halving': 11, 'excess': 0}
# {'block': 115800351, 'timestamp': 3070042871, 'emitted_tao': 20991797.90625, 'halving': 11, 'excess': 0}
# {'block': 116520351, 'timestamp': 3078682871, 'emitted_tao': 20992149.46875, 'halving': 11, 'excess': 0}
# {'block': 117240351, 'timestamp': 3087322871, 'emitted_tao': 20992501.03125, 'halving': 11, 'excess': 0}
# {'block': 117960351, 'timestamp': 3095962871, 'emitted_tao': 20992852.59375, 'halving': 11, 'excess': 0}
# {'block': 118680351, 'timestamp': 3104602871, 'emitted_tao': 20993204.15625, 'halving': 11, 'excess': 0}
# {'block': 119400351, 'timestamp': 3113242871, 'emitted_tao': 20993555.71875, 'halving': 11, 'excess': 0}
# {'block': 120120351, 'timestamp': 3121882871, 'emitted_tao': 20993907.28125, 'halving': 11, 'excess': 0}
# {'block': 120840351, 'timestamp': 3130522871, 'emitted_tao': 20994258.84375, 'halving': 11, 'excess': 0}
# {'block': 121560351, 'timestamp': 3139162871, 'emitted_tao': 20994610.40625, 'halving': 11, 'excess': 0}
# {'block': 122280351, 'timestamp': 3147802871, 'emitted_tao': 20994926.8125, 'halving': 12, 'excess': 0}
# {'block': 123000351, 'timestamp': 3156442871, 'emitted_tao': 20995102.59375, 'halving': 12, 'excess': 0}
# {'block': 123720351, 'timestamp': 3165082871, 'emitted_tao': 20995278.375, 'halving': 12, 'excess': 0}
# {'block': 124440351, 'timestamp': 3173722871, 'emitted_tao': 20995454.15625, 'halving': 12, 'excess': 0}
# {'block': 125160351, 'timestamp': 3182362871, 'emitted_tao': 20995629.9375, 'halving': 12, 'excess': 0}
# {'block': 125880351, 'timestamp': 3191002871, 'emitted_tao': 20995805.71875, 'halving': 12, 'excess': 0}
# {'block': 126600351, 'timestamp': 3199642871, 'emitted_tao': 20995981.5, 'halving': 12, 'excess': 0}
# {'block': 127320351, 'timestamp': 3208282871, 'emitted_tao': 20996157.28125, 'halving': 12, 'excess': 0}
# {'block': 128040351, 'timestamp': 3216922871, 'emitted_tao': 20996333.0625, 'halving': 12, 'excess': 0}
# {'block': 128760351, 'timestamp': 3225562871, 'emitted_tao': 20996508.84375, 'halving': 12, 'excess': 0}
# {'block': 129480351, 'timestamp': 3234202871, 'emitted_tao': 20996684.625, 'halving': 12, 'excess': 0}
# {'block': 130200351, 'timestamp': 3242842871, 'emitted_tao': 20996860.40625, 'halving': 12, 'excess': 0}
# {'block': 130920351, 'timestamp': 3251482871, 'emitted_tao': 20997036.1875, 'halving': 12, 'excess': 0}
# {'block': 131640351, 'timestamp': 3260122871, 'emitted_tao': 20997211.96875, 'halving': 12, 'excess': 0}
# {'block': 132360351, 'timestamp': 3268762871, 'emitted_tao': 20997387.75, 'halving': 12, 'excess': 0}
# {'block': 133080351, 'timestamp': 3277402871, 'emitted_tao': 20997502.0078125, 'halving': 13, 'excess': 0}
# {'block': 133800351, 'timestamp': 3286042871, 'emitted_tao': 20997589.8984375, 'halving': 13, 'excess': 0}
# {'block': 134520351, 'timestamp': 3294682871, 'emitted_tao': 20997677.7890625, 'halving': 13, 'excess': 0}
# {'block': 135240351, 'timestamp': 3303322871, 'emitted_tao': 20997765.6796875, 'halving': 13, 'excess': 0}
# {'block': 135960351, 'timestamp': 3311962871, 'emitted_tao': 20997853.5703125, 'halving': 13, 'excess': 0}
# {'block': 136680351, 'timestamp': 3320602871, 'emitted_tao': 20997941.4609375, 'halving': 13, 'excess': 0}
# {'block': 137400351, 'timestamp': 3329242871, 'emitted_tao': 20998029.3515625, 'halving': 13, 'excess': 0}
# {'block': 138120351, 'timestamp': 3337882871, 'emitted_tao': 20998117.2421875, 'halving': 13, 'excess': 0}
# {'block': 138840351, 'timestamp': 3346522871, 'emitted_tao': 20998205.1328125, 'halving': 13, 'excess': 0}
# {'block': 139560351, 'timestamp': 3355162871, 'emitted_tao': 20998293.0234375, 'halving': 13, 'excess': 0}
# {'block': 140280351, 'timestamp': 3363802871, 'emitted_tao': 20998380.9140625, 'halving': 13, 'excess': 0}
# {'block': 141000351, 'timestamp': 3372442871, 'emitted_tao': 20998468.8046875, 'halving': 13, 'excess': 0}
# {'block': 141720351, 'timestamp': 3381082871, 'emitted_tao': 20998556.6953125, 'halving': 13, 'excess': 0}
# {'block': 142440351, 'timestamp': 3389722871, 'emitted_tao': 20998644.5859375, 'halving': 13, 'excess': 0}
# {'block': 143160351, 'timestamp': 3398362871, 'emitted_tao': 20998728.08203125, 'halving': 14, 'excess': 0}
# {'block': 143880351, 'timestamp': 3407002871, 'emitted_tao': 20998772.02734375, 'halving': 14, 'excess': 0}
# {'block': 144600351, 'timestamp': 3415642871, 'emitted_tao': 20998815.97265625, 'halving': 14, 'excess': 0}
# {'block': 145320351, 'timestamp': 3424282871, 'emitted_tao': 20998859.91796875, 'halving': 14, 'excess': 0}
# {'block': 146040351, 'timestamp': 3432922871, 'emitted_tao': 20998903.86328125, 'halving': 14, 'excess': 0}
# {'block': 146760351, 'timestamp': 3441562871, 'emitted_tao': 20998947.80859375, 'halving': 14, 'excess': 0}
# {'block': 147480351, 'timestamp': 3450202871, 'emitted_tao': 20998991.75390625, 'halving': 14, 'excess': 0}
# {'block': 148200351, 'timestamp': 3458842871, 'emitted_tao': 20999035.69921875, 'halving': 14, 'excess': 0}
# {'block': 148920351, 'timestamp': 3467482871, 'emitted_tao': 20999079.64453125, 'halving': 14, 'excess': 0}
# {'block': 149640351, 'timestamp': 3476122871, 'emitted_tao': 20999123.58984375, 'halving': 14, 'excess': 0}
# {'block': 150360351, 'timestamp': 3484762871, 'emitted_tao': 20999167.53515625, 'halving': 14, 'excess': 0}
# {'block': 151080351, 'timestamp': 3493402871, 'emitted_tao': 20999211.48046875, 'halving': 14, 'excess': 0}
# {'block': 151800351, 'timestamp': 3502042871, 'emitted_tao': 20999255.42578125, 'halving': 14, 'excess': 0}
# {'block': 152520351, 'timestamp': 3510682871, 'emitted_tao': 20999299.37109375, 'halving': 14, 'excess': 0}
# {'block': 153240351, 'timestamp': 3519322871, 'emitted_tao': 20999343.31640625, 'halving': 14, 'excess': 0}
# {'block': 153960351, 'timestamp': 3527962871, 'emitted_tao': 20999374.078125, 'halving': 15, 'excess': 0}
# {'block': 154680351, 'timestamp': 3536602871, 'emitted_tao': 20999396.05078125, 'halving': 15, 'excess': 0}
# {'block': 155400351, 'timestamp': 3545242871, 'emitted_tao': 20999418.0234375, 'halving': 15, 'excess': 0}
# {'block': 156120351, 'timestamp': 3553882871, 'emitted_tao': 20999439.99609375, 'halving': 15, 'excess': 0}
# {'block': 156840351, 'timestamp': 3562522871, 'emitted_tao': 20999461.96875, 'halving': 15, 'excess': 0}
# {'block': 157560351, 'timestamp': 3571162871, 'emitted_tao': 20999483.94140625, 'halving': 15, 'excess': 0}
# {'block': 158280351, 'timestamp': 3579802871, 'emitted_tao': 20999505.9140625, 'halving': 15, 'excess': 0}
# {'block': 159000351, 'timestamp': 3588442871, 'emitted_tao': 20999527.88671875, 'halving': 15, 'excess': 0}
# {'block': 159720351, 'timestamp': 3597082871, 'emitted_tao': 20999549.859375, 'halving': 15, 'excess': 0}
# {'block': 160440351, 'timestamp': 3605722871, 'emitted_tao': 20999571.83203125, 'halving': 15, 'excess': 0}
# {'block': 161160351, 'timestamp': 3614362871, 'emitted_tao': 20999593.8046875, 'halving': 15, 'excess': 0}
# {'block': 161880351, 'timestamp': 3623002871, 'emitted_tao': 20999615.77734375, 'halving': 15, 'excess': 0}
# {'block': 162600351, 'timestamp': 3631642871, 'emitted_tao': 20999637.75, 'halving': 15, 'excess': 0}
# {'block': 163320351, 'timestamp': 3640282871, 'emitted_tao': 20999659.72265625, 'halving': 15, 'excess': 0}
# {'block': 164040351, 'timestamp': 3648922871, 'emitted_tao': 20999681.6953125, 'halving': 16, 'excess': 0}
# {'block': 164760351, 'timestamp': 3657562871, 'emitted_tao': 20999692.681640625, 'halving': 16, 'excess': 0}
# {'block': 165480351, 'timestamp': 3666202871, 'emitted_tao': 20999703.66796875, 'halving': 16, 'excess': 0}
# {'block': 166200351, 'timestamp': 3674842871, 'emitted_tao': 20999714.654296875, 'halving': 16, 'excess': 0}
# {'block': 166920351, 'timestamp': 3683482871, 'emitted_tao': 20999725.640625, 'halving': 16, 'excess': 0}
# {'block': 167640351, 'timestamp': 3692122871, 'emitted_tao': 20999736.626953125, 'halving': 16, 'excess': 0}
# {'block': 168360351, 'timestamp': 3700762871, 'emitted_tao': 20999747.61328125, 'halving': 16, 'excess': 0}
# {'block': 169080351, 'timestamp': 3709402871, 'emitted_tao': 20999758.599609375, 'halving': 16, 'excess': 0}
# {'block': 169800351, 'timestamp': 3718042871, 'emitted_tao': 20999769.5859375, 'halving': 16, 'excess': 0}
# {'block': 170520351, 'timestamp': 3726682871, 'emitted_tao': 20999780.572265625, 'halving': 16, 'excess': 0}
# {'block': 171240351, 'timestamp': 3735322871, 'emitted_tao': 20999791.55859375, 'halving': 16, 'excess': 0}
# {'block': 171960351, 'timestamp': 3743962871, 'emitted_tao': 20999802.544921875, 'halving': 16, 'excess': 0}
# {'block': 172680351, 'timestamp': 3752602871, 'emitted_tao': 20999813.53125, 'halving': 16, 'excess': 0}
# {'block': 173400351, 'timestamp': 3761242871, 'emitted_tao': 20999824.517578125, 'halving': 16, 'excess': 0}
# {'block': 174120351, 'timestamp': 3769882871, 'emitted_tao': 20999835.50390625, 'halving': 16, 'excess': 0}
# {'block': 174840351, 'timestamp': 3778522871, 'emitted_tao': 20999843.194335938, 'halving': 17, 'excess': 0}
# {'block': 175560351, 'timestamp': 3787162871, 'emitted_tao': 20999848.6875, 'halving': 17, 'excess': 0}
# {'block': 176280351, 'timestamp': 3795802871, 'emitted_tao': 20999854.180664062, 'halving': 17, 'excess': 0}
# {'block': 177000351, 'timestamp': 3804442871, 'emitted_tao': 20999859.673828125, 'halving': 17, 'excess': 0}
# {'block': 177720351, 'timestamp': 3813082871, 'emitted_tao': 20999865.166992188, 'halving': 17, 'excess': 0}
# {'block': 178440351, 'timestamp': 3821722871, 'emitted_tao': 20999870.66015625, 'halving': 17, 'excess': 0}
# {'block': 179160351, 'timestamp': 3830362871, 'emitted_tao': 20999876.153320312, 'halving': 17, 'excess': 0}
# {'block': 179880351, 'timestamp': 3839002871, 'emitted_tao': 20999881.646484375, 'halving': 17, 'excess': 0}
# {'block': 180600351, 'timestamp': 3847642871, 'emitted_tao': 20999887.139648438, 'halving': 17, 'excess': 0}
# {'block': 181320351, 'timestamp': 3856282871, 'emitted_tao': 20999892.6328125, 'halving': 17, 'excess': 0}
# {'block': 182040351, 'timestamp': 3864922871, 'emitted_tao': 20999898.125976562, 'halving': 17, 'excess': 0}
# {'block': 182760351, 'timestamp': 3873562871, 'emitted_tao': 20999903.619140625, 'halving': 17, 'excess': 0}
# {'block': 183480351, 'timestamp': 3882202871, 'emitted_tao': 20999909.112304688, 'halving': 17, 'excess': 0}
# {'block': 184200351, 'timestamp': 3890842871, 'emitted_tao': 20999914.60546875, 'halving': 17, 'excess': 0}
# {'block': 184920351, 'timestamp': 3899482871, 'emitted_tao': 20999920.098632812, 'halving': 18, 'excess': 0}
# {'block': 185640351, 'timestamp': 3908122871, 'emitted_tao': 20999922.845214844, 'halving': 18, 'excess': 0}
# {'block': 186360351, 'timestamp': 3916762871, 'emitted_tao': 20999925.591796875, 'halving': 18, 'excess': 0}
# {'block': 187080351, 'timestamp': 3925402871, 'emitted_tao': 20999928.338378906, 'halving': 18, 'excess': 0}
# {'block': 187800351, 'timestamp': 3934042871, 'emitted_tao': 20999931.084960938, 'halving': 18, 'excess': 0}
# {'block': 188520351, 'timestamp': 3942682871, 'emitted_tao': 20999933.83154297, 'halving': 18, 'excess': 0}
# {'block': 189240351, 'timestamp': 3951322871, 'emitted_tao': 20999936.578125, 'halving': 18, 'excess': 0}
# {'block': 189960351, 'timestamp': 3959962871, 'emitted_tao': 20999939.32470703, 'halving': 18, 'excess': 0}
# {'block': 190680351, 'timestamp': 3968602871, 'emitted_tao': 20999942.071289062, 'halving': 18, 'excess': 0}
# {'block': 191400351, 'timestamp': 3977242871, 'emitted_tao': 20999944.817871094, 'halving': 18, 'excess': 0}
# {'block': 192120351, 'timestamp': 3985882871, 'emitted_tao': 20999947.564453125, 'halving': 18, 'excess': 0}
# {'block': 192840351, 'timestamp': 3994522871, 'emitted_tao': 20999950.311035156, 'halving': 18, 'excess': 0}
# {'block': 193560351, 'timestamp': 4003162871, 'emitted_tao': 20999953.057617188, 'halving': 18, 'excess': 0}
# {'block': 194280351, 'timestamp': 4011802871, 'emitted_tao': 20999955.80419922, 'halving': 18, 'excess': 0}
# {'block': 195000351, 'timestamp': 4020442871, 'emitted_tao': 20999958.55078125, 'halving': 18, 'excess': 0}
# {'block': 195720351, 'timestamp': 4029082871, 'emitted_tao': 20999960.748046875, 'halving': 19, 'excess': 0}
# {'block': 196440351, 'timestamp': 4037722871, 'emitted_tao': 20999962.12133789, 'halving': 19, 'excess': 0}
# {'block': 197160351, 'timestamp': 4046362871, 'emitted_tao': 20999963.494628906, 'halving': 19, 'excess': 0}
# {'block': 197880351, 'timestamp': 4055002871, 'emitted_tao': 20999964.867919922, 'halving': 19, 'excess': 0}
# {'block': 198600351, 'timestamp': 4063642871, 'emitted_tao': 20999966.241210938, 'halving': 19, 'excess': 0}
# {'block': 199320351, 'timestamp': 4072282871, 'emitted_tao': 20999967.614501953, 'halving': 19, 'excess': 0}
# {'block': 200040351, 'timestamp': 4080922871, 'emitted_tao': 20999968.98779297, 'halving': 19, 'excess': 0}
# {'block': 200760351, 'timestamp': 4089562871, 'emitted_tao': 20999970.361083984, 'halving': 19, 'excess': 0}
# {'block': 201480351, 'timestamp': 4098202871, 'emitted_tao': 20999971.734375, 'halving': 19, 'excess': 0}
# {'block': 202200351, 'timestamp': 4106842871, 'emitted_tao': 20999973.107666016, 'halving': 19, 'excess': 0}
# {'block': 202920351, 'timestamp': 4115482871, 'emitted_tao': 20999974.48095703, 'halving': 19, 'excess': 0}
# {'block': 203640351, 'timestamp': 4124122871, 'emitted_tao': 20999975.854248047, 'halving': 19, 'excess': 0}
# {'block': 204360351, 'timestamp': 4132762871, 'emitted_tao': 20999977.227539062, 'halving': 19, 'excess': 0}
# {'block': 205080351, 'timestamp': 4141402871, 'emitted_tao': 20999978.600830078, 'halving': 19, 'excess': 0}
# {'block': 205800351, 'timestamp': 4150042871, 'emitted_tao': 20999979.974121094, 'halving': 20, 'excess': 0}
# {'block': 206520351, 'timestamp': 4158682871, 'emitted_tao': 20999980.6607666, 'halving': 20, 'excess': 0}
# {'block': 207240351, 'timestamp': 4167322871, 'emitted_tao': 20999981.34741211, 'halving': 20, 'excess': 0}
# {'block': 207960351, 'timestamp': 4175962871, 'emitted_tao': 20999982.034057617, 'halving': 20, 'excess': 0}
# {'block': 208680351, 'timestamp': 4184602871, 'emitted_tao': 20999982.720703125, 'halving': 20, 'excess': 0}
# {'block': 209400351, 'timestamp': 4193242871, 'emitted_tao': 20999983.407348633, 'halving': 20, 'excess': 0}
# {'block': 210120351, 'timestamp': 4201882871, 'emitted_tao': 20999984.09399414, 'halving': 20, 'excess': 0}
# {'block': 210840351, 'timestamp': 4210522871, 'emitted_tao': 20999984.78063965, 'halving': 20, 'excess': 0}
# {'block': 211560351, 'timestamp': 4219162871, 'emitted_tao': 20999985.467285156, 'halving': 20, 'excess': 0}
# {'block': 212280351, 'timestamp': 4227802871, 'emitted_tao': 20999986.153930664, 'halving': 20, 'excess': 0}
# {'block': 213000351, 'timestamp': 4236442871, 'emitted_tao': 20999986.840576172, 'halving': 20, 'excess': 0}
# {'block': 213720351, 'timestamp': 4245082871, 'emitted_tao': 20999987.52722168, 'halving': 20, 'excess': 0}
# {'block': 214440351, 'timestamp': 4253722871, 'emitted_tao': 20999988.213867188, 'halving': 20, 'excess': 0}
# {'block': 215160351, 'timestamp': 4262362871, 'emitted_tao': 20999988.900512695, 'halving': 20, 'excess': 0}
# {'block': 215880351, 'timestamp': 4271002871, 'emitted_tao': 20999989.587158203, 'halving': 20, 'excess': 0}
# {'block': 216600351, 'timestamp': 4279642871, 'emitted_tao': 20999990.13647461, 'halving': 21, 'excess': 0}
# {'block': 217320351, 'timestamp': 4288282871, 'emitted_tao': 20999990.479797363, 'halving': 21, 'excess': 0}
# {'block': 218040351, 'timestamp': 4296922871, 'emitted_tao': 20999990.823120117, 'halving': 21, 'excess': 0}
# {'block': 218760351, 'timestamp': 4305562871, 'emitted_tao': 20999991.16644287, 'halving': 21, 'excess': 0}
# {'block': 219480351, 'timestamp': 4314202871, 'emitted_tao': 20999991.509765625, 'halving': 21, 'excess': 0}
# {'block': 220200351, 'timestamp': 4322842871, 'emitted_tao': 20999991.85308838, 'halving': 21, 'excess': 0}
# {'block': 220920351, 'timestamp': 4331482871, 'emitted_tao': 20999992.196411133, 'halving': 21, 'excess': 0}
# {'block': 221640351, 'timestamp': 4340122871, 'emitted_tao': 20999992.539733887, 'halving': 21, 'excess': 0}
# {'block': 222360351, 'timestamp': 4348762871, 'emitted_tao': 20999992.88305664, 'halving': 21, 'excess': 0}
# {'block': 223080351, 'timestamp': 4357402871, 'emitted_tao': 20999993.226379395, 'halving': 21, 'excess': 0}
# {'block': 223800351, 'timestamp': 4366042871, 'emitted_tao': 20999993.56970215, 'halving': 21, 'excess': 0}
# {'block': 224520351, 'timestamp': 4374682871, 'emitted_tao': 20999993.913024902, 'halving': 21, 'excess': 0}
# {'block': 225240351, 'timestamp': 4383322871, 'emitted_tao': 20999994.256347656, 'halving': 21, 'excess': 0}
# {'block': 225960351, 'timestamp': 4391962871, 'emitted_tao': 20999994.59967041, 'halving': 21, 'excess': 0}
# {'block': 226680351, 'timestamp': 4400602871, 'emitted_tao': 20999994.942993164, 'halving': 21, 'excess': 0}
# {'block': 227400351, 'timestamp': 4409242871, 'emitted_tao': 20999995.148986816, 'halving': 22, 'excess': 0}
# {'block': 228120351, 'timestamp': 4417882871, 'emitted_tao': 20999995.320648193, 'halving': 22, 'excess': 0}
# {'block': 228840351, 'timestamp': 4426522871, 'emitted_tao': 20999995.49230957, 'halving': 22, 'excess': 0}
# {'block': 229560351, 'timestamp': 4435162871, 'emitted_tao': 20999995.663970947, 'halving': 22, 'excess': 0}
# {'block': 230280351, 'timestamp': 4443802871, 'emitted_tao': 20999995.835632324, 'halving': 22, 'excess': 0}
# {'block': 231000351, 'timestamp': 4452442871, 'emitted_tao': 20999996.0072937, 'halving': 22, 'excess': 0}
# {'block': 231720351, 'timestamp': 4461082871, 'emitted_tao': 20999996.178955078, 'halving': 22, 'excess': 0}
# {'block': 232440351, 'timestamp': 4469722871, 'emitted_tao': 20999996.350616455, 'halving': 22, 'excess': 0}
# {'block': 233160351, 'timestamp': 4478362871, 'emitted_tao': 20999996.522277832, 'halving': 22, 'excess': 0}
# {'block': 233880351, 'timestamp': 4487002871, 'emitted_tao': 20999996.69393921, 'halving': 22, 'excess': 0}
# {'block': 234600351, 'timestamp': 4495642871, 'emitted_tao': 20999996.865600586, 'halving': 22, 'excess': 0}
# {'block': 235320351, 'timestamp': 4504282871, 'emitted_tao': 20999997.037261963, 'halving': 22, 'excess': 0}
# {'block': 236040351, 'timestamp': 4512922871, 'emitted_tao': 20999997.20892334, 'halving': 22, 'excess': 0}
# {'block': 236760351, 'timestamp': 4521562871, 'emitted_tao': 20999997.380584717, 'halving': 22, 'excess': 0}
# {'block': 237480351, 'timestamp': 4530202871, 'emitted_tao': 20999997.526496887, 'halving': 23, 'excess': 0}
# {'block': 238200351, 'timestamp': 4538842871, 'emitted_tao': 20999997.612327576, 'halving': 23, 'excess': 0}
# {'block': 238920351, 'timestamp': 4547482871, 'emitted_tao': 20999997.698158264, 'halving': 23, 'excess': 0}
# {'block': 239640351, 'timestamp': 4556122871, 'emitted_tao': 20999997.783988953, 'halving': 23, 'excess': 0}
# {'block': 240360351, 'timestamp': 4564762871, 'emitted_tao': 20999997.86981964, 'halving': 23, 'excess': 0}
# {'block': 241080351, 'timestamp': 4573402871, 'emitted_tao': 20999997.95565033, 'halving': 23, 'excess': 0}
# {'block': 241800351, 'timestamp': 4582042871, 'emitted_tao': 20999998.041481018, 'halving': 23, 'excess': 0}
# {'block': 242520351, 'timestamp': 4590682871, 'emitted_tao': 20999998.127311707, 'halving': 23, 'excess': 0}
# {'block': 243240351, 'timestamp': 4599322871, 'emitted_tao': 20999998.213142395, 'halving': 23, 'excess': 0}
# {'block': 243960351, 'timestamp': 4607962871, 'emitted_tao': 20999998.298973083, 'halving': 23, 'excess': 0}
# {'block': 244680351, 'timestamp': 4616602871, 'emitted_tao': 20999998.384803772, 'halving': 23, 'excess': 0}
# {'block': 245400351, 'timestamp': 4625242871, 'emitted_tao': 20999998.47063446, 'halving': 23, 'excess': 0}
# {'block': 246120351, 'timestamp': 4633882871, 'emitted_tao': 20999998.55646515, 'halving': 23, 'excess': 0}
# {'block': 246840351, 'timestamp': 4642522871, 'emitted_tao': 20999998.642295837, 'halving': 23, 'excess': 0}
# {'block': 247560351, 'timestamp': 4651162871, 'emitted_tao': 20999998.728126526, 'halving': 23, 'excess': 0}
# {'block': 248280351, 'timestamp': 4659802871, 'emitted_tao': 20999998.783916473, 'halving': 24, 'excess': 0}
# {'block': 249000351, 'timestamp': 4668442871, 'emitted_tao': 20999998.826831818, 'halving': 24, 'excess': 0}
# {'block': 249720351, 'timestamp': 4677082871, 'emitted_tao': 20999998.869747162, 'halving': 24, 'excess': 0}
# {'block': 250440351, 'timestamp': 4685722871, 'emitted_tao': 20999998.912662506, 'halving': 24, 'excess': 0}
# {'block': 251160351, 'timestamp': 4694362871, 'emitted_tao': 20999998.95557785, 'halving': 24, 'excess': 0}
# {'block': 251880351, 'timestamp': 4703002871, 'emitted_tao': 20999998.998493195, 'halving': 24, 'excess': 0}
# 3432

# %%
print(tao_blocks[3000])
# Out:
# {'block': 220920351, 'timestamp': 4331482871, 'emitted_tao': 20999992.196411133, 'halving': 21, 'excess': 0}

# %%
subnets = [{"name": "OG_subnet1",          "start": 1739482871,"price": .01, "emission_data":{}, "last_alpha_block":0, "last_alpha_timestamp":0}, 
           {"name": "dtao_subnet",          "start": 1756762871,"price": .01, "emission_data":{}, "last_alpha_block":0, "last_alpha_timestamp":0},
           {"name": "first_halving_subnet",    "start": 1834522871,"price": .01, "emission_data":{}, "last_alpha_block":0, "last_alpha_timestamp":0},
           {"name": "first_halving_subnet2",    "start": 1877722871,"price": .05, "emission_data":{}, "last_alpha_block":0, "last_alpha_timestamp":0},
           {"name": "second_halving_sn", "start": 1990042871,"price":  .01, "emission_data":{},"last_alpha_block":0, "last_alpha_timestamp":0}, 
           {"name": "fourth_halving_sn", "start": 2206042871,"price":  .01, "emission_data":{},"last_alpha_block":0, "last_alpha_timestamp":0},
          ]
n = len(subnets)
subnet_excesses = [{} for _ in range(n)]


#we need to recalculate the tao_blocks each time... it holds the excess
tao_blocks =get_tao_blocks(False)

#at each block we need to calculate the emission for each SN
for tao_block in tao_blocks:
    tao_block_number  = tao_block['block']
    if tao_block_number < 251880351:
        #get the tao details
        tao_time = tao_block['timestamp']
        tao_block_number  = tao_block['block']
        tao_halving = tao_block['halving']

        #we need all the alpha halvings form the last calculation
        alpha_havlings = []
        halving_differences = []
        last_timestamp  = tao_time - 86400*days_entry
        for subnet in subnets:
            if last_timestamp in subnet['emission_data']:
                alpha_halving = subnet['emission_data'][last_timestamp]['alpha_halving']
                alpha_havlings.append(alpha_halving)
                halving_differences.append(alpha_halving - tao_halving)
        #print(tao_time, tao_halving, alpha_havlings)
        #magic
        #for now - equal disrtibution
        #every subnet that meets the criteria will receive 1/difference_conter tao
        difference_counter = 0
        for difference in halving_differences:
            if difference >0:
                difference_counter+=1
        

        for i, subnet in enumerate(subnets):
            start = subnet['start']
            price = subnet['price']
            if start <= last_timestamp:
                
                #this subnet has started emitting alpha
                #lets get the halving at the last entry
                if last_timestamp in subnet['emission_data']:
                    alpha_halving = subnet['emission_data'][last_timestamp]['alpha_halving']
                    tao_in =subnet['emission_data'][last_timestamp]['tao_in']
                    alpha_in =subnet['emission_data'][last_timestamp]['alpha_in']
                    alpha_out = subnet['emission_data'][last_timestamp]['alpha_out']
                else:
                    #new subnet
                    alpha_halving=0
                    tao_in =1
                    alpha_in =1
                    alpha_out = 1
                #print(tao_time, subnet['name'], start, tao_halving, alpha_halving)
                alpha_block_number = tao_block_number
                alpha_time = tao_time
                total_alpha  = alpha_in + alpha_out
    
                #now we change emission pattersn based on halvings
                if alpha_halving> tao_halving:
                    #print("excess")
                    #OG subnet
                    #this is the max tao_in - based on the tao halving
                    max_tao_in = (7200*days_entry)* (0.5**tao_halving)*price  #(blocks * tao per block)
                    #actual - using alpha halving since alpha is bigger than tao
                    actual_tao_in = (7200*days_entry)* (0.5**alpha_halving)*price
                    excess_tao = max_tao_in - actual_tao_in
                    
                    #increment the tao in the pool
                    tao_in += actual_tao_in
                    #add the excess into the tao_block
                    tao_block['excess'] += excess_tao
                    #alpha in is based on alpha halving in this case
                    alpha_in += (7200*days_entry)*  ((0.5**alpha_halving)*price)/price #change in tao_in /price
                    #alpha out is unchanged
                    alpha_out +=(7200*days_entry) * (0.5**alpha_halving)
                    total_alpha  = alpha_in + alpha_out
                    #print(max_tao_in, actual_tao_in, excess_tao, alpha_in, total_alpha)
                    #update the alpha halving
                    if total_alpha <token_max-200: 
                        alpha_halving = math.floor(math.log((token_max - total_alpha)/token_max)/math.log(0.5))
                        #print("excess alpha halving", alpha_block_number,alpha_halving)
                        subnet['emission_data'][alpha_time] ={"block":alpha_block_number, "timestamp":alpha_time, "tao_in":tao_in, "alpha_in": alpha_in, "alpha_out": alpha_out,"alpha_halving":alpha_halving, "tao_halving": tao_halving}
                        subnet_excesses[i][alpha_time] = {"max_tao_in":max_tao_in, "actual_tao_in":actual_tao_in, "excess_tao":excess_tao}
                    else:
                        subnet['emission_data'][alpha_time] = subnet['emission_data'][last_timestamp]  
                        #the last block where alpha is emitted
                        if subnet['last_alpha_block'] ==0:
                            subnet['last_alpha_block'] = alpha_block_number
                            subnet['last_alpha_timestamp'] = alpha_time
                elif alpha_halving == tao_halving:
                    #old emission.. no difference added in 
                    block_tao_in = (7200*days_entry)* (0.5**tao_halving)*price 
                    block_alpha_in = (7200*days_entry)*  ((0.5**tao_halving)*price)/price 
                    tao_in +=   block_tao_in
                    alpha_in += block_alpha_in
                    #a_out is unchanged
                    alpha_out +=(7200*days_entry) * (0.5**alpha_halving)
                    total_alpha  = alpha_in + alpha_out
                    if total_alpha <token_max-200:
                        alpha_halving = math.floor(math.log((token_max - total_alpha)/token_max)/math.log(0.5))
                        #print(alpha_time, "alpha_halving_math",alpha_halving)
                        #if alpha_halving ==2:
                            #print("total alpha",total_alpha)
                            
                        subnet['emission_data'][alpha_time] ={"block":alpha_block_number, "timestamp":alpha_time, "tao_in":tao_in, "alpha_in": alpha_in, "alpha_out": alpha_out,"alpha_halving":alpha_halving, "tao_halving": tao_halving}
                    else:
                        subnet['emission_data'][alpha_time] = subnet['emission_data'][last_timestamp]
                        #the last block where alpha is emitted
                        if subnet['last_alpha_block'] ==0:
                            subnet['last_alpha_block'] = alpha_block_number
                            subnet['last_alpha_timestamp'] = alpha_time
                    
                else:    
                    #this is a newer subnet with a much lower emission. 
                    #We can increase the tao_in and the alpha in with the excess tao
                    total_excess = tao_block['excess']
    
                    #today - simple ratio distribution
                    if difference_counter>0:
                        subnet_excess = total_excess/difference_counter
                    else:
                        subnet_excess = 0
                    #tao_in gets a percentage of the excess
                    #alpha in gets that same percentage - converted to alpha
                    #emission is based on tha tao halving
                    block_tao_in = (7200*days_entry)* (0.5**tao_halving)*price + subnet_excess
                    block_alpha_in = (7200*days_entry)*  ((0.5**tao_halving)*price)/price + subnet_excess/price
                    tao_in +=   block_tao_in
                    alpha_in += block_alpha_in
                    #a_out is unchanged
                    alpha_out +=(7200*days_entry) * (0.5**alpha_halving)
                    total_alpha  = alpha_in + alpha_out
                    if total_alpha <token_max-200:
                        alpha_halving = math.floor(math.log((token_max - total_alpha)/token_max)/math.log(0.5))
                        #print(alpha_time, "alpha_halving_math",alpha_halving)
                        #if alpha_halving ==2:
                            #print("total alpha",total_alpha)
                            
                        subnet['emission_data'][alpha_time] ={"block":alpha_block_number, "timestamp":alpha_time, "tao_in":tao_in, "alpha_in": alpha_in, "alpha_out": alpha_out,"alpha_halving":alpha_halving, "tao_halving": tao_halving}
                    else:
                        subnet['emission_data'][alpha_time] = subnet['emission_data'][last_timestamp]
                        #the last block where alpha is emitted
                        if subnet['last_alpha_block'] ==0:
                            subnet['last_alpha_block'] = alpha_block_number
                            subnet['last_alpha_timestamp'] = alpha_time
# Out:
# 3432

# %%
print(alpha_havlings)
print(halving_differences)
print(len(tao_blocks))
for subnet in subnets:
    temp_time = subnet['last_alpha_timestamp']
    date_str = datetime.utcfromtimestamp(temp_time).strftime("%m/%d/%Y")
    print(date_str)
# Out:
# [16, 16, 16, 16, 16, 16]
# [-8, -8, -8, -8, -8, -8]
# 3432
# 10/08/2058
# 08/14/2059
# 09/27/2062
# 12/20/2065
# 01/08/2070
# 07/27/2091

# %%
plt.figure(figsize=(10, 6))

for i, subnet in enumerate(subnets):
    emission_data = list(subnet["emission_data"].values())
    blocks = [d["block"] for d in emission_data]
    tao_in = [d["tao_in"] for d in emission_data]
    alpha_in = [d["alpha_in"] for d in emission_data]
    plt.plot(blocks, tao_in, marker="o", label=subnet["name"], color=colours[i])
    # add vertical line if last_alpha_block exists
    if "last_alpha_block" in subnet:
        plt.axvline(
            x=subnet["last_alpha_block"],
            color="gray",
            linestyle="--",
            alpha=0.7,
            label=f"{subnet['name']} last_alpha_block"
        )

chart_data = alpha_in

plt.xlabel("Block")
plt.ylabel("tao_in")
plt.title("tao_in vs Block per Subnet")
plt.legend()
plt.grid(True)

# Force full block numbers and rotate
plt.ticklabel_format(style='plain', axis='x')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
for subnet in subnets:
    temp_time = subnet['last_alpha_timestamp']
    date_str = datetime.utcfromtimestamp(temp_time).strftime("%m/%d/%Y")
    print(date_str)
# Out:
# 10/08/2058
# 08/14/2059
# 09/27/2062
# 12/20/2065
# 01/08/2070
# 07/27/2091

# %%
current_key = 1945978871

print(subnets[0]['emission_data'][current_key])
print(subnet_excesses[0][current_key])

print(subnets[1]['emission_data'][current_key])
print(subnet_excesses[1][current_key])

for taoblock in tao_blocks:
    if taoblock['timestamp']== current_key:
        print(taoblock)
print("-------------------")
# Out:
# {'block': 22128351, 'timestamp': 1945978871, 'tao_in': 81901.0, 'alpha_in': 8190001.0, 'alpha_out': 10314001.0, 'alpha_halving': 3, 'tao_halving': 2}
# {'max_tao_in': 180.0, 'actual_tao_in': 90.0, 'excess_tao': 90.0}
# {'block': 22128351, 'timestamp': 1945978871, 'tao_in': 70561.0, 'alpha_in': 7056001.0, 'alpha_out': 10440001.0, 'alpha_halving': 2, 'tao_halving': 2}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 7
#       4 print(subnet_excesses[0][current_key])
#       6 print(subnets[1]['emission_data'][current_key])
# ----> 7 print(subnet_excesses[1][current_key])
#       9 for taoblock in tao_blocks:
#      10     if taoblock['timestamp']== current_key:
#
# KeyError: 1945978871

# %%
print(len(subnet_excesses[0]))
print(len(subnet_excesses[1]))
print(len(subnet_excesses[2]))
print(len(subnet_excesses[3]))
print(len(subnet_excesses[4]))
print(len(subnet_excesses[5]))
# Out:
# 1009
# 979
# 866
# 747
# 598
# 0
